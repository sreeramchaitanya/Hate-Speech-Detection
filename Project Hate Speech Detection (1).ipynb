# %%
""" importing important libraries

numpy is broadly used for scientific computing with Python such as linear algebra, random samples and statistics.
pandas is used for data manipulation and analysis

"""
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('labeled_data.csv')

# %%
# data.info() is used to get a quick overview of the dataset and its properties.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24783 entries, 0 to 24782
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          24783 non-null  int64
#  1   count               24783 non-null  int64
#  2   hate_speech         24783 non-null  int64
#  3   offensive_language  24783 non-null  int64
#  4   neither             24783 non-null  int64
#  5   class               24783 non-null  int64
#  6   tweet               24783 non-null  object
# dtypes: int64(6), object(1)
# memory usage: 1.3+ MB

# %%
data.head(10)
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
# 5           5      3            1                   2        0      1
# 6           6      3            0                   3        0      1
# 7           7      3            0                   3        0      1
# 8           8      3            0                   3        0      1
# 9           9      3            1                   2        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# ...

# %%
# data.isnull() give info about any null values present in dataset. True indicates null values. False indicates not null values
data.isnull()
# Out:
#        Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           False  False        False               False    False  False
# 1           False  False        False               False    False  False
# 2           False  False        False               False    False  False
# 3           False  False        False               False    False  False
# 4           False  False        False               False    False  False
# ...           ...    ...          ...                 ...      ...    ...
# 24778       False  False        False               False    False  False
# 24779       False  False        False               False    False  False
# 24780       False  False        False               False    False  False
# 24781       False  False        False               False    False  False
# 24782       False  False        False               False    False  False
#
#        tweet
# 0      False
# 1      False
# 2      False
# 3      False
# ...

# %%
# data.isnull().sum() give quick summary of missing values in dataset.
data.isnull().sum()
# Out:
# Unnamed: 0            0
# count                 0
# hate_speech           0
# offensive_language    0
# neither               0
# class                 0
# tweet                 0
# dtype: int64

# %%
#data.describe() give overveiw of statisical analysis of data.
data.describe()
# Out:
#          Unnamed: 0         count   hate_speech  offensive_language  \
# count  24783.000000  24783.000000  24783.000000        24783.000000
# mean   12681.192027      3.243473      0.280515            2.413711
# std     7299.553863      0.883060      0.631851            1.399459
# min        0.000000      3.000000      0.000000            0.000000
# 25%     6372.500000      3.000000      0.000000            2.000000
# 50%    12703.000000      3.000000      0.000000            3.000000
# 75%    18995.500000      3.000000      0.000000            3.000000
# max    25296.000000      9.000000      7.000000            9.000000
#
#             neither         class
# count  24783.000000  24783.000000
# mean       0.549247      1.110277
# std        1.113299      0.462089
# min        0.000000      0.000000
# 25%        0.000000      1.000000
# 50%        0.000000      1.000000
# 75%        0.000000      1.000000
# max        9.000000      2.000000

# %%
# altering the labels in class column for better understanding of Hate Speech, offensive language and Neither.
data["labels"] = data["class"].map({0: "Hate Speech", 1: "offensive Language", 2:"Neither Hate or offensive"})

# %%
data.head(10)
# Out:
#    Unnamed: 0  count  hate_speech  offensive_language  neither  class  \
# 0           0      3            0                   0        3      2
# 1           1      3            0                   3        0      1
# 2           2      3            0                   3        0      1
# 3           3      3            0                   2        1      1
# 4           4      6            0                   6        0      1
# 5           5      3            1                   2        0      1
# 6           6      3            0                   3        0      1
# 7           7      3            0                   3        0      1
# 8           8      3            0                   3        0      1
# 9           9      3            1                   2        0      1
#
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# ...

# %%
# Sampling Data for better understanding of data.
data1 = data[["tweet","labels"]]

# %%
data1
# Out:
#                                                    tweet  \
# 0      !!! RT @mayasolovely: As a woman you shouldn't...
# 1      !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# ...                                                  ...
# 24778  you's a muthaf***in lie &#8220;@LifeAsKing: @2...
# 24779  you've gone and broke the wrong heart baby, an...
# 24780  young buck wanna eat!!.. dat nigguh like I ain...
# 24781              youu got wild bitches tellin you lies
# 24782  ~~Ruffled | Ntac Eileen Dahlia - Beautiful col...
#
#                           labels
# 0      Neither Hate or offensive
# 1             offensive Language
# 2             offensive Language
# 3             offensive Language
# 4             offensive Language
# ...                          ...
# 24778         offensive Language
# ...

# %%
data1.head(10)
# Out:
#                                                tweet  \
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...
# 6  !!!!!!"@__BrighterDays: I can not just sit up ...
# 7  !!!!&#8220;@selfiequeenbri: cause I'm tired of...
# 8  " &amp; you might not get ya bitch back &amp; ...
# 9  " @rhythmixx_ :hobbies include: fighting Maria...
#
#                       labels
# 0  Neither Hate or offensive
# 1         offensive Language
# 2         offensive Language
# 3         offensive Language
# 4         offensive Language
# 5         offensive Language
# 6         offensive Language
# 7         offensive Language
# 8         offensive Language
# 9         offensive Language

# %%
import re # re stands for regular expression. Regular expressions are a powerful tool for searching and manipulating strings. They can be used to find patterns in text, extract data, and perform other complex operations.
import nltk # nltk is a leading platform for building Python programs to work with human language data. stands for natural language tool kit
print(nltk.__version__)
import string # string is a module in Python that provides support for common string operations.
# Out:
# 3.8.1

# %%
nltk.download("stopwords") # Download stopwords.
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords # importing stopwords which is a part of nltk. used for removing stopwords.
stop_words = set(stopwords.words('english')) # The statement stop_words = set(stopwords.words('english')) creates a set of English stop words. Stop words are commonly used words that don't carry much meaning on their own, such as "the", "a", "an", "in", and "of".

# %%
stemmer = nltk.stem.SnowballStemmer('english') # SnowballStemmer is an algorithm that reduces words to their root form, known as the stem.

# %%
def clean_data(text):  # function to clean the data.
    text = str(text).lower() # Converts the text to lowercase.
    text = re.sub('https?://\S+|www\.S+', '', text) # Removes URLs.
    text = re.sub('\[.*?\]', '', text) # Removes text in square brackets.
    text = re.sub('<.*?>+', '', text) # Removes HTML tags.
    text = text + re.sub('[%s]'%re.escape(string.punctuation), '', text) # Removes punctuations. such as "!", "?", ".", ",", ";", ":", "-", "'", '"', and "(".
    text = re.sub('\n', '', text) # Removes new line characters.
    text = re.sub('\w*\d\w*', '', text) # Removes words containing numbers.
    text = re.sub(r"[^\w\s]", '', text)  # Remove special characters
    return text

# %% [markdown]
# # `text = re.sub('https?://\S+|www\.S+', '', text)`
#
# `re.sub()`: This function is used to **perform substitutions** on a string using a regular expression.
#
# `'https?://\S+|www\.S+'`: This regular expression matches two patterns:
#
# `https?://\S+: `This matches any URL that starts with "http://" or "https://", followed by any number of non-whitespace characters.
#
# `www\.S+:` This matches any URL that starts with "www." followed by any number of non-whitespace characters.
#
# `'  ': `This is the replacement string, which is an empty string. This means that any URLs or web addresses matched by the regular expression will be removed from the text.

# %% [markdown]
# # `text = re.sub('\[.*?\]', '', text)`
#
# `'\[.*?\]':` This regular expression matches any sequence of characters that is enclosed in square brackets.
#
# `\[:` This matches the opening square bracket [.
#
# `.*?:` This matches any number of characters (including none) using a non-greedy match.
#
# `\]:` This matches the closing square bracket ].

# %% [markdown]
# # `text = re.sub('<.*?>+', '', text)`
# `'<.*?>+':` This regular expression matches any sequence of characters that is enclosed in angle brackets < and >.
#
# `<:` This matches the opening angle bracket <.
#
# `.*?:` This matches any number of characters (including none) using a non-greedy match.
#
# `>: `This matches the closing angle bracket >.
#
# `+:` This matches one or more occurrences of the preceding pattern.

# %% [markdown]
# # `text = text + re.sub('[%s]'%re.escape(string.punctuation), '', text)`
#
# `re.escape(string.punctuation): `This escapes all the special characters in the string.punctuation constant, which contains all the punctuation characters in Python.
#
# `'[%s]'%re.escape(string.punctuation):` This creates a regular expression that matches any character that is in the escaped string.punctuation.

# %% [markdown]
# # `text = re.sub('\w*\d\w*', '', text)`
#
# `'\w*\d\w*':` This regular expression matches any sequence of characters that:
#
# 1. Starts with zero or more word characters (\w*)
# 2. Followed by one or more digits (\d)
# 3. Followed by zero or more word characters (\w*)

# %% [markdown]
# # `text = re.sub(r"[^\w\s]", '', text)`
#
# `r"[^\w\s]": `This regular expression matches any character that is not:
# 1. A word character (\w)
# 2. A space character or Whitespace (\s)

# %% [markdown]
# ---

# %%
data1["tweet"] = data1["tweet"].apply(clean_data) # applies the clean_data function to the "tweet" column of the dataframe.
# Out:
# <ipython-input-19-74b90fc593d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["tweet"] = data1["tweet"].apply(clean_data) # applies the clean_data function to the "tweet" column of the dataframe.

# %%
data1
# Out:
#                                                    tweet  \
# 0       rt mayasolovely as a woman you shouldnt compl...
# 1       rt  boy dats coldtyga dwn bad for cuffin dat ...
# 2       rt urkindofbrand dawg rt  you ever fuck a bit...
# 3       rt c_g_anderson viva_based she look like a tr...
# 4       rt shenikaroberts the shit you hear about me ...
# ...                                                  ...
# 24778  yous a muthafin lie lifeasking  corey_emanuel ...
# 24779  youve gone and broke the wrong heart baby and ...
# 24780  young buck wanna eat dat nigguh like i aint fu...
# 24781  youu got wild bitches tellin you liesyouu got ...
# 24782  ruffled  ntac eileen dahlia  beautiful color c...
#
#                           labels
# 0      Neither Hate or offensive
# 1             offensive Language
# 2             offensive Language
# 3             offensive Language
# 4             offensive Language
# ...                          ...
# 24778         offensive Language
# ...

# %%
x = np.array(data1["tweet"]) # "tweet" is the feature.
y = np.array(data1["labels"]) # "labels" is the target variable.

# %%
x
# Out:
# array([' rt mayasolovely as a woman you shouldnt complain about cleaning up your house amp as a man you should always take the trash out rt mayasolovely as a woman you shouldnt complain about cleaning up your house amp as a man you should always take the trash out',
#        ' rt  boy dats coldtyga dwn bad for cuffin dat hoe in the  place rt  boy dats coldtyga dwn bad for cuffin dat hoe in the  place',
#        ' rt urkindofbrand dawg rt  you ever fuck a bitch and she start to cry you be confused as shit rt urkindofbrand dawg rt  you ever fuck a bitch and she start to cry you be confused as shit',
#        ...,
#        'young buck wanna eat dat nigguh like i aint fuckin dis up againyoung buck wanna eat dat nigguh like i aint fuckin dis up again',
#        'youu got wild bitches tellin you liesyouu got wild bitches tellin you lies',
# ...

# %%
# The CountVectorizer class is used to convert a collection of text documents into a matrix of token counts.
# The sklearn.feature_extraction.text module in scikit-learn provides a number of tools for extracting features from text data. These features can then be used for various machine learning tasks such as text classification, clustering, and information retrieval.

from sklearn.feature_extraction.text import CountVectorizer #
from sklearn.model_selection import train_test_split

# The train_test_split function in scikit-learn is used to split a dataset into two subsets: a training set and a test set. This is a common practice in machine learning to evaluate the performance of a machine learning model.
# Syntax : train_test_split(X, y, test_size=0.25, train_size=None, random_state=None, shuffle=True, stratify=None)

# %%
cv = CountVectorizer()

# %%
x = cv.fit_transform(x) # transform() method of CountVectorizer class is used to convert a collection of text documents to a matrix of token counts.

# %%
x
# Out:
# <24783x46225 sparse matrix of type '<class 'numpy.int64'>'
# 	with 315790 stored elements in Compressed Sparse Row format>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 42)

# %%
x_train
# Out:
# <16604x46225 sparse matrix of type '<class 'numpy.int64'>'
# 	with 211700 stored elements in Compressed Sparse Row format>

# %%
#Building ML model
from sklearn.tree import DecisionTreeClassifier # DecisionTreeClassifier is a machine learning algorithm that is used for classification tasks.

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train) # Fit the model to training data.
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(x_test) # Predict the target values for the test data.

# %%
#Confusion Matrix
from sklearn.metrics import confusion_matrix # Confusion matrix function is used to check the accuracy of the model.
cr = confusion_matrix(y_test, y_pred)
cr
# Out:
# array([[ 140,   50,  275],
#        [  29, 1183,  167],
#        [ 203,  238, 5894]])

# %%
import seaborn as sns # Seaborn is a Python data visualization library based on matplotlib.
import matplotlib.pyplot as plt # matplotlib is a Python 2D plotting library.
# Inline backend of matplotlib which allows us to display the plot in the notebook.
# %matplotlib inline

# %%
sns.heatmap(cr, annot = True, fmt = 'd', cmap = 'magma') # annot = True to annotate cells,
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8823817092554102

# %%
sample = "Lets unite and kill all the people who are stupid"
sample = clean_data(sample)

# %%
data2 = cv.transform([sample]).toarray()

# %%
data2
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
dt.predict(data2)
# Out:
# array(['offensive Language'], dtype=object)
